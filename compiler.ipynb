# %%
# !python --version
# !g++ -v
# Out:
# Python 3.6.9
# Using built-in specs.
# COLLECT_GCC=g++
# COLLECT_LTO_WRAPPER=/usr/lib/gcc/x86_64-linux-gnu/7/lto-wrapper
# OFFLOAD_TARGET_NAMES=nvptx-none
# OFFLOAD_TARGET_DEFAULT=1
# Target: x86_64-linux-gnu
# ...

# %%
# !sudo add-apt-repository -y ppa:maarten-fonville/protobuf
# !sudo apt-get update
# !apt-get install libzmq5 libzmq5-dev libprotobuf-dev protobuf-compiler
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Ign:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages
# ...

# %%
# !gdown --id 1owPuQyAFVefrnw4ZOhbpLUbiaHYBjX0t
# !unzip ns3-gym.zip
# !mv /content/ns3-gym /usr/ns3-gym
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ns3-gym/build/src/internet/model/tcp-prr-recovery.cc.1.o
#   inflating: ns3-gym/build/src/internet/model/tcp-recovery-ops.cc.1.o
#   inflating: ns3-gym/build/src/internet/model/tcp-rx-buffer.cc.1.o
#   inflating: ns3-gym/build/src/internet/model/tcp-scalable.cc.1.o
#   inflating: ns3-gym/build/src/internet/model/tcp-socket-base.cc.1.o
#   inflating: ns3-gym/build/src/internet/model/tcp-socket-factory-impl.cc.1.o
#   inflating: ns3-gym/build/src/internet/model/tcp-socket-factory.cc.1.o
#   inflating: ns3-gym/build/src/internet/model/tcp-socket-state.cc.1.o
#   inflating: ns3-gym/build/src/internet/model/tcp-socket.cc.1.o
#   inflating: ns3-gym/build/src/internet/model/tcp-tx-buffer.cc.1.o
#   inflating: ns3-gym/build/src/internet/model/tcp-vegas.cc.1.o
#   inflating: ns3-gym/build/src/internet/model/tcp-veno.cc.1.o
#   inflating: ns3-gym/build/src/internet/model/tcp-westwood.cc.1.o
# ...

# %%
# %cd /usr/ns3-gym
# Out:
# /usr/ns3-gym

# %%
# %ls
# Out:
# Setting top to                           : /content/ns3-gym
# Setting out to                           : /content/ns3-gym/build
# Checking for 'gcc' (C compiler)          : /usr/bin/gcc
# Checking for cc version                  : 7.5.0
# Checking for 'g++' (C++ compiler)        : /usr/bin/g++
# Checking for compilation flag -Wl,--soname=foo support : ok
# Checking for compilation flag -std=c++11 support       : ok
# Checking for program 'python'                          : /usr/bin/python3
# Checking for python version >= 2.3                     : 3.6.9
# python-config                                          : /usr/bin/python3-config
# Asking python-config for pyembed '--cflags --libs --ldflags' flags : yes
# Testing pyembed configuration                                      : yes
# Asking python-config for pyext '--cflags --libs --ldflags' flags   : yes
# Testing pyext configuration                                        : yes
# ...

# %%
# !./waf --check-profile
# Out:
# Waf: Entering directory `/usr/ns3-gym/build'
# Build profile: debug

# %%
pip install ./contrib/opengym/model/ns3gym
# Out:
# Processing ./contrib/opengym/model/ns3gym
# ...
#   Created wheel for ns3gym: filename=ns3gym-0.1.0-cp36-none-any.whl size=10469 sha256=fcc387b43f094ec2d535dd270324a6e6bd1a35aeb23c80f689af61d91b208968
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3m_5pqu5/wheels/90/15/ff/3112a9c257e42d1139db989027dda43d5d8f36a6808ebae966
# Successfully built ns3gym
# ...
#   Found existing installation: ns3gym 0.1.0
#     Uninstalling ns3gym-0.1.0:
#       Successfully uninstalled ns3gym-0.1.0
# ...

# %%
# !./waf --check-profile
# Out:
# Waf: Entering directory `/usr/ns3-gym/build'
# Build profile: debug

# %%
# !./waf --run hello-simulator
# Out:
# Waf: Entering directory `/usr/ns3-gym/build'
# [   1/2632] Compiling install-ns3-header: ns3/parabolic-antenna-model.h
# [   2/2632] Compiling install-ns3-header: ns3/antenna-model.h
# [   3/2632] Compiling install-ns3-header: ns3/cosine-antenna-model.h
# [   4/2632] Compiling install-ns3-header: ns3/isotropic-antenna-model.h
# [   5/2632] Compiling install-ns3-header: ns3/angles.h
# [   6/2632] Compiling install-ns3-header: ns3/aodv-rtable.h
# [   7/2632] Compiling install-ns3-header: ns3/aodv-routing-protocol.h
# [   8/2632] Compiling install-ns3-header: ns3/aodv-dpd.h
# [   9/2632] Compiling install-ns3-header: ns3/aodv-neighbor.h
# [  10/2632] Compiling install-ns3-header: ns3/aodv-packet.h
# [  11/2632] Compiling install-ns3-header: ns3/aodv-helper.h
# [  12/2632] Compiling install-ns3-header: ns3/aodv-rqueue.h
# [  13/2632] Compiling install-ns3-header: ns3/aodv-id-cache.h
# [  14/2632] Compiling install-ns3-header: ns3/application-packet-probe.h
# ...

# %%
# !./contrib/opengym/examples/opengym/simple_test.py
# Out:
# Got new port for ns3gm interface:  7447
# Traceback (most recent call last):
#   File "./contrib/opengym/examples/opengym/simple_test.py", line 14, in <module>
#   File "/usr/local/lib/python3.6/dist-packages/gym/envs/registration.py", line 145, in make
#     return registry.make(id, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/gym/envs/registration.py", line 90, in make
#     env = spec.make(**kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/gym/envs/registration.py", line 60, in make
#     env = cls(**_kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ns3gym/ns3env.py", line 381, in __init__
#     self.ns3ZmqBridge.initialize_env(self.stepTime)
#   File "/usr/local/lib/python3.6/dist-packages/ns3gym/ns3env.py", line 151, in initialize_env
#     request = self.socket.recv()
#   File "zmq/backend/cython/socket.pyx", line 791, in zmq.backend.cython.socket.Socket.recv
# ...
